# %% [markdown]
# -sandbox
# ### 1. Delete Data files if exists

# %%
dbutils.fs.rm("/airlines.csv")
dbutils.fs.rm("/airports.csv")
dbutils.fs.rm("/flights_data_01.csv")
dbutils.fs.rm("/flights_data_02.csv")
dbutils.fs.rm("/flights_data_03.csv")
dbutils.fs.rm("/flights_data_04.csv")
dbutils.fs.rm("/flights_data_05.csv")
dbutils.fs.rm("/flights_data_06.csv")
dbutils.fs.rm("/flights_data_07.csv")
dbutils.fs.rm("/flights_data_08.csv")

# %% [markdown]
# -sandbox
# ### 2. Copy Data files

# %%
# %sh
wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1tlwiaK74rmUlqxZocyZU_eFsHMnaS1L2' -O /dbfs/airlines.csv
wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1vHhDvqMacy7eEPdv4kdXDXvbrcx3-oz8' -O /dbfs/airports.csv
wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1MllabRPjjqx2ysZhj9wQySvX5PazkXGV' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1MllabRPjjqx2ysZhj9wQySvX5PazkXGV" -O /dbfs/flights_data_01.csv && rm -rf /tmp/cookies.txt
wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1QFRheI8EO0NV9SorTg2AZiLa1RkqQmuu' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1QFRheI8EO0NV9SorTg2AZiLa1RkqQmuu" -O /dbfs/flights_data_02.csv && rm -rf /tmp/cookies.txt
wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1CMN4UmI1-OHv96nZDwvas2Ku9v4OTC__' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1CMN4UmI1-OHv96nZDwvas2Ku9v4OTC__" -O /dbfs/flights_data_03.csv && rm -rf /tmp/cookies.txt
wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1CV-zqFSqU0z-GrdoRMYhAmTprjQ5vHc-' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1CV-zqFSqU0z-GrdoRMYhAmTprjQ5vHc-" -O /dbfs/flights_data_04.csv && rm -rf /tmp/cookies.txt
wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1L7IBJeuDdvMNkOR96O3Jq-qacMNrGuoy' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1L7IBJeuDdvMNkOR96O3Jq-qacMNrGuoy" -O /dbfs/flights_data_05.csv && rm -rf /tmp/cookies.txt
wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1aHEx-gUD4tJgV4Nz-Dqh0WTHvJH9DCw1' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1aHEx-gUD4tJgV4Nz-Dqh0WTHvJH9DCw1" -O /dbfs/flights_data_06.csv && rm -rf /tmp/cookies.txt
wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1VTlw_j3J24A5J5yudtxD4oW0VAX6HSTO' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1VTlw_j3J24A5J5yudtxD4oW0VAX6HSTO" -O /dbfs/flights_data_07.csv && rm -rf /tmp/cookies.txt
wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1hqUEYdP4w6sF4KhXVaYGSIMsaQl-Z0Xx' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1hqUEYdP4w6sF4KhXVaYGSIMsaQl-Z0Xx" -O /dbfs/flights_data_08.csv && rm -rf /tmp/cookies.txt

# %% [markdown]
# -sandbox
# ### 3. Check created files

# %%
dbutils.fs.ls("/airlines.csv")
dbutils.fs.ls("/airports.csv")
dbutils.fs.ls("/flights_data_01.csv")
dbutils.fs.ls("/flights_data_02.csv")
dbutils.fs.ls("/flights_data_03.csv")
dbutils.fs.ls("/flights_data_04.csv")
dbutils.fs.ls("/flights_data_05.csv")
dbutils.fs.ls("/flights_data_06.csv")
dbutils.fs.ls("/flights_data_07.csv")
dbutils.fs.ls("/flights_data_08.csv")
